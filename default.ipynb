# %% [markdown]
# # Import Packages

# %%
import pandas as pd

# %% [markdown]
# # Load Data

# %%
price_sensitive_path = '/Users/chohasong/Desktop/streamlit_datasets/default/'

# %%
fitness_watch_default = pd.read_csv(price_sensitive_path +'fitness_watch/run_aggregated_experiment_data.csv')

# %%
fitness_watch_default['model_name'].unique()
# Out:
# array(['gpt-5.1', 'claude-opus-4-5-20251101', 'gpt-5',
#        'gpt-4.1-2025-04-14'], dtype=object)

# %%
# sanity check
fitness_watch_default.groupby(['model_name'])['selected'].sum()
# Out:
# model_name
# claude-opus-4-5-20251101    1
# gpt-4.1-2025-04-14          1
# gpt-5                       1
# gpt-5.1                     0
# Name: selected, dtype: int64

# %%
fitness_watch_default['prompt'].value_counts()
# Out:
# prompt
# ...

# %%
iphone_16_pro_cover_default = pd.read_csv(price_sensitive_path +'iphone_16_pro_cover/run_aggregated_experiment_data.csv')

# %%
iphone_16_pro_cover_default.groupby(['model_name'])['selected'].sum()
# Out:
# model_name
# claude-opus-4-5-20251101    1
# gpt-4.1-2025-04-14          1
# gpt-5                       1
# Name: selected, dtype: int64

# %%
mousepad_default = pd.read_csv(price_sensitive_path +'mousepad/run_aggregated_experiment_data.csv')

# %%
mousepad_default.groupby(['model_name'])['selected'].sum()
# Out:
# model_name
# claude-opus-4-5-20251101    1
# gpt-4.1-2025-04-14          1
# gpt-5                       1
# gpt-5.1                     1
# Name: selected, dtype: int64

# %%
office_lamp_default = pd.read_csv(price_sensitive_path +'office_lamp/run_aggregated_experiment_data.csv')

# %%
office_lamp_default.groupby(['model_name'])['selected'].sum()
# Out:
# model_name
# claude-opus-4-5-20251101    1
# gpt-4.1-2025-04-14          1
# gpt-5                       1
# gpt-5.1                     0
# Name: selected, dtype: int64

# %%
toilet_paper_default = pd.read_csv(price_sensitive_path +'toilet_paper/run_aggregated_experiment_data.csv')

# %%
toilet_paper_default.groupby(['model_name'])['selected'].sum()
# Out:
# model_name
# claude-opus-4-5-20251101    1
# gpt-4.1-2025-04-14          2
# gpt-5                       1
# gpt-5.1                     0
# Name: selected, dtype: int64

# %%
toilet_paper_default[toilet_paper_default['selected']!=0]
# Out:
#     Unnamed: 0  assigned_position  best_seller  desired_choice  discounted  \
# 11       20227                  3        False              -1       False
# 23       20231                  7        False              -1       False
# 27       20227                  3        False              -1       False
#
#      experiment_label  experiment_number  \
# 11  master_experiment                 28
# 23  master_experiment                 28
# 27  master_experiment                 28
#
#                                             image_url  limited_time  \
# 11  https://m.media-amazon.com/images/I/81StZsCHUD...         False
# 23  https://m.media-amazon.com/images/I/81a9MAHSji...         False
# 27  https://m.media-amazon.com/images/I/81StZsCHUD...         False
#
#     low_stock  ...  stock_quantity  \
# 11      False  ...              43
# 23      False  ...              25
# 27      False  ...              43
#
#                                                 title  \
# ...

# %%
stapler_default = pd.read_csv(price_sensitive_path +'stapler/run_aggregated_experiment_data.csv')

# %%
stapler_default.groupby(['model_name'])['selected'].sum()
# Out:
# model_name
# claude-opus-4-5-20251101    1
# gpt-4.1-2025-04-14          1
# gpt-5                       1
# gpt-5.1                     1
# Name: selected, dtype: int64

# %%
stapler = pd.read_csv(price_sensitive_path +'stapler/run_aggregated_experiment_data.csv')
stapler.groupby(['model_name'])['selected'].sum()
# Out:
# model_name
# claude-opus-4-5-20251101    1
# gpt-4.1-2025-04-14          1
# gpt-5                       1
# gpt-5.1                     1
# Name: selected, dtype: int64

# %%
toothpaste_price_sensitive = pd.read_csv(price_sensitive_path +'toothpaste/run_aggregated_experiment_data.csv')
toothpaste_price_sensitive.groupby(['model_name'])['selected'].sum()
# Out:
# model_name
# claude-opus-4-5-20251101    1
# gpt-4.1-2025-04-14          1
# gpt-5                       1
# gpt-5.1                     0
# Name: selected, dtype: int64

# %%
toothpaste_price_sensitive['prompt'].value_counts()
# Out:
# prompt
# ...

# %%
washing_machine_price_sensitive = pd.read_csv(price_sensitive_path +'washing_machine/run_aggregated_experiment_data.csv')
washing_machine_price_sensitive.groupby(['model_name'])['selected'].sum()
# Out:
# model_name
# claude-opus-4-5-20251101    1
# gpt-4.1-2025-04-14          1
# gpt-5                       1
# gpt-5.1                     1
# Name: selected, dtype: int64
