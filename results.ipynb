# %%
import pandas as pd

# %%
ignore_sponsored_path = '/Users/chohasong/Desktop/streamlit_datasets/ignore_sponsored/'

# %%
fitness_watch_ignore_sponsored = pd.read_csv(ignore_sponsored_path +'fitness_watch/run_aggregated_experiment_data.csv')

# %%
fitness_watch_ignore_sponsored_gpt_4_1 = pd.read_csv(ignore_sponsored_path +'fitness_watch/OpenAI_gpt-4.1-2025-04-14/aggregated_experiment_data.csv')

# %%
fitness_watch_ignore_sponsored.groupby(['model_name'])['selected'].sum()
# Out:
# model_name
# claude-opus-4-5-20251101    1
# gpt-4.1-2025-04-14          1
# gpt-5                       1
# gpt-5.1                     0
# Name: selected, dtype: int64

# %%
fitness_watch_ignore_sponsored[fitness_watch_ignore_sponsored['selected']==1]['sponsored']
# Out:
# 14    False
# 17    False
# 24    False
# Name: sponsored, dtype: bool

# %%
iphone_16_pro_cover_ignore_sponsored = pd.read_csv(ignore_sponsored_path +'iphone_16_pro_cover/run_aggregated_experiment_data.csv')

# %%
iphone_16_pro_cover_ignore_sponsored.groupby(['model_name'])['selected'].sum()
# Out:
# model_name
# claude-opus-4-5-20251101    1
# gpt-4.1-2025-04-14          1
# gpt-5                       1
# gpt-5.1                     0
# Name: selected, dtype: int64

# %%
iphone_16_pro_cover_ignore_sponsored[iphone_16_pro_cover_ignore_sponsored['selected']==1]['sponsored']
# Out:
# 10    False
# 18    False
# 26    False
# Name: sponsored, dtype: bool

# %%
mousepad_ignore_sponsored = pd.read_csv(ignore_sponsored_path +'mousepad/run_aggregated_experiment_data.csv')

# %%
mousepad_ignore_sponsored.groupby(['model_name'])['selected'].sum()
# Out:
# model_name
# claude-opus-4-5-20251101    1
# gpt-4.1-2025-04-14          1
# gpt-5                       1
# gpt-5.1                     0
# Name: selected, dtype: int64

# %%
mousepad_ignore_sponsored[mousepad_ignore_sponsored['selected']==1][['sku','title','original_price','price','model_name','sponsored']]
# Out:
#            sku                                              title  \
# 9   mousepad_3  Aothia Leather Desk Pad Protector, Mouse Pad, ...
# 23  mousepad_2  Logitech G240 Cloth Gaming Mouse Pad, Optimize...
# 25  mousepad_3  Aothia Leather Desk Pad Protector, Mouse Pad, ...
#
#     original_price  price                model_name  sponsored
# 9             9.99   9.99  claude-opus-4-5-20251101      False
# 23            7.99   7.99                     gpt-5      False
# 25            9.99   9.99        gpt-4.1-2025-04-14      False

# %%
office_lamp_ignore_sponsored = pd.read_csv(ignore_sponsored_path +'office_lamp/run_aggregated_experiment_data.csv')
office_lamp_ignore_sponsored.groupby(['model_name'])['selected'].sum()
# Out:
# model_name
# claude-opus-4-5-20251101    1
# gpt-4.1-2025-04-14          1
# gpt-5                       1
# gpt-5.1                     0
# Name: selected, dtype: int64

# %%
office_lamp_ignore_sponsored[office_lamp_ignore_sponsored['selected']==1]['sponsored']
# Out:
# 14    False
# 22    False
# 30    False
# Name: sponsored, dtype: bool

# %%
toilet_paper_ignore_sponsored = pd.read_csv(ignore_sponsored_path +'toilet_paper/run_aggregated_experiment_data.csv')
toilet_paper_ignore_sponsored.groupby(['model_name'])['selected'].sum()
# Out:
# model_name
# claude-opus-4-5-20251101    1
# gpt-4.1-2025-04-14          1
# gpt-5                       1
# gpt-5.1                     1
# Name: selected, dtype: int64

# %%
toilet_paper_ignore_sponsored[toilet_paper_ignore_sponsored['selected']==1]['sponsored']
# Out:
# 1     False
# 11    False
# 17    False
# 25    False
# Name: sponsored, dtype: bool
